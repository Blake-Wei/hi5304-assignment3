# %%
import pandas as pd

# %%
measurements_timeseries = pd.read_csv("measurements_analysis_ready.csv")
visits_thyroid = pd.read_csv("visits_analysis_ready.csv")
thyroid_testing = pd.read_csv("thyroid_testing_cohort.csv")

# %%
measurements_timeseries.head()
# Out:
#    person_id  gender_concept_id gender_clean  year_of_birth  \
# 0  894170912               8507            M         1982.0
# 1  191126884               8532            F         2003.0
# 2  101262469               8532            F         2013.0
# 3  908390849               8507            M         1966.0
# 4  939482390               8507            M         2007.0
#
#    age_at_measurement age_group  race_concept_id                 race_clean  \
# 0                43.0     35-49             8527                      White
# 1                22.0     18-34                0                    Unknown
# 2                12.0      0-17             8527                      White
# 3                59.0     50-64             8516  Black or African American
# 4                18.0     18-34             8527                      White
#
#    ethnicity_concept_id         ethnicity_clean  ...   ALT  Serum_Creatinine  \
# 0              38003564  Not Hispanic or Latino  ...   NaN               NaN
# 1                     0                 Unknown  ...   NaN              0.93
# 2              38003564  Not Hispanic or Latino  ...   NaN               NaN
# 3              38003564  Not Hispanic or Latino  ...   NaN               NaN
# 4              38003564  Not Hispanic or Latino  ...  80.0              1.16
#
#   Serum_Albumin  tsh  t3  t4  has_tsh  has_t3  has_t4  has_any_thyroid_test
# 0           NaN  NaN NaN NaN        0       0       0                     0
# 1           NaN  NaN NaN NaN        0       0       0                     0
# 2           NaN  NaN NaN NaN        0       0       0                     0
# 3           NaN  NaN NaN NaN        0       0       0                     0
# 4           4.2  NaN NaN NaN        0       0       0                     0
#
# [5 rows x 29 columns]

# %%
measurements_timeseries.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2913028 entries, 0 to 2913027
# Data columns (total 29 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   person_id             int64
#  1   gender_concept_id     int64
#  2   gender_clean          str
#  3   year_of_birth         float64
#  4   age_at_measurement    float64
#  5   age_group             str
#  6   race_concept_id       int64
#  7   race_clean            str
#  8   ethnicity_concept_id  int64
#  9   ethnicity_clean       str
#  10  measurement_date      str
#  11  measurement_year      int64
#  12  measurement_month     str
#  13  weight                float64
#  14  bmi                   float64
#  15  triglycerides         float64
#  16  hba1c                 float64
#  17  Serum_Glucose         float64
#  18  AST                   float64
#  19  ALT                   float64
#  20  Serum_Creatinine      float64
#  21  Serum_Albumin         float64
#  22  tsh                   float64
#  23  t3                    float64
#  24  t4                    float64
#  25  has_tsh               int64
#  26  has_t3                int64
#  27  has_t4                int64
#  28  has_any_thyroid_test  int64
# dtypes: float64(14), int64(9), str(6)
# memory usage: 644.5 MB

# %%
visits_thyroid.head()
# Out:
#    person_id  gender_concept_id gender gender_clean  year_of_birth  \
# 0  924609883               8532      F            F         1956.0
# 1  426015508               8532      F            F         1932.0
# 2  178569665               8532      F            F         1979.0
# 3  749236674               8507      M            M         1964.0
# 4   82232424               8532      F            F         1994.0
#
#    age_at_visit age_group                       race  \
# 0          69.0       65+                      White
# 1          93.0       65+                      White
# 2          46.0     35-49  Black or African American
# 3          61.0     50-64                      White
# 4          31.0     18-34                      Other
#
#                   race_clean               ethnicity  ... visit_start_date  \
# 0                      White  Not Hispanic or Latino  ...       2025-11-21
# 1                      White  Not Hispanic or Latino  ...       2025-08-01
# 2  Black or African American  Not Hispanic or Latino  ...       2025-05-15
# 3                      White  Not Hispanic or Latino  ...       2025-08-19
# 4                      Other  Not Hispanic or Latino  ...       2025-06-10
#
#    visit_end_date visit_duration_days same_day_visit_flag  long_visit_flag_7d  \
# 0      2026-01-18                58.0                   0                   1
# 1      2025-08-03                 2.0                   0                   0
# 2      2025-06-08                24.0                   0                   1
# 3      2025-09-20                32.0                   0                   1
# 4      2025-08-23                74.0                   0                   1
#
#   long_visit_flag_30d office_related_flag inpatient_related_flag  \
# 0                   1                   1                      0
# 1                   0                   1                      0
# 2                   0                   0                      0
# 3                   1                   1                      0
# 4                   1                   1                      0
#
#   emergency_related_flag telehealth_flag
# 0                      0               0
# 1                      0               0
# 2                      0               1
# 3                      0               0
# 4                      0               0
#
# [5 rows x 28 columns]

# %%
visits_thyroid.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 179124 entries, 0 to 179123
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   person_id                    179124 non-null  int64
#  1   gender_concept_id            179124 non-null  int64
#  2   gender                       179124 non-null  str
#  3   gender_clean                 179124 non-null  str
#  4   year_of_birth                178760 non-null  float64
#  5   age_at_visit                 178760 non-null  float64
#  6   age_group                    178760 non-null  str
#  7   race                         179124 non-null  str
#  8   race_clean                   179124 non-null  str
#  9   ethnicity                    179124 non-null  str
#  10  ethnicity_clean              179124 non-null  str
#  11  snomed_condition_concept_id  179124 non-null  int64
#  12  condition_description        179124 non-null  str
#  13  condition_description_clean  179124 non-null  str
#  14  visit_concept_id             179124 non-null  int64
#  15  visit_type                   179124 non-null  str
#  16  visit_type_clean             179124 non-null  str
#  17  visit_type_group             179124 non-null  str
#  18  visit_start_date             179124 non-null  str
#  19  visit_end_date               179124 non-null  str
#  20  visit_duration_days          179124 non-null  float64
#  21  same_day_visit_flag          179124 non-null  int64
#  22  long_visit_flag_7d           179124 non-null  int64
#  23  long_visit_flag_30d          179124 non-null  int64
#  24  office_related_flag          179124 non-null  int64
#  25  inpatient_related_flag       179124 non-null  int64
#  26  emergency_related_flag       179124 non-null  int64
#  27  telehealth_flag              179124 non-null  int64
# dtypes: float64(3), int64(11), str(14)
# memory usage: 38.3 MB

# %%
thyroid_testing.head()
# Out:
#    person_id  gender_concept_id gender_clean  year_of_birth  \
# 0       2092               8532            F         1971.0
# 1      10620               8507            M         1951.0
# 2      21584               8507            M         1982.0
# 3      42122               8532            F         1958.0
# 4      59957               8507            M         1973.0
#
#    age_at_measurement age_group  race_concept_id  \
# 0                54.0     50-64             8527
# 1                74.0       65+             8527
# 2                43.0     35-49             8657
# 3                67.0       65+             8527
# 4                52.0     50-64                0
#
#                                   race_clean  ethnicity_concept_id  \
# 0                                      White              38003564
# 1                                      White              38003564
# 2  Native Hawaiian or Other Pacific Islander              38003564
# 3                                      White              38003564
# 4                                    Unknown              38003564
#
#           ethnicity_clean  ...   ALT  Serum_Creatinine Serum_Albumin  tsh  \
# 0  Not Hispanic or Latino  ...  30.0              0.78           4.3  NaN
# 1  Not Hispanic or Latino  ...  27.0              1.06           4.3  NaN
# 2  Not Hispanic or Latino  ...  46.0              1.03           4.2  NaN
# 3  Not Hispanic or Latino  ...  11.0              0.73           4.5  NaN
# 4  Not Hispanic or Latino  ...  17.0              0.81           4.3  NaN
#
#      t3    t4  has_tsh  has_t3  has_t4  has_any_thyroid_test
# 0   NaN  1.20        0       0       1                     1
# 1   NaN  0.97        0       0       1                     1
# 2   NaN  0.89        0       0       1                     1
# 3  82.5  0.92        0       1       1                     1
# 4   2.8  0.95        0       1       1                     1
#
# [5 rows x 29 columns]

# %%
thyroid_testing.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 42300 entries, 0 to 42299
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   person_id             42300 non-null  int64
#  1   gender_concept_id     42300 non-null  int64
#  2   gender_clean          42300 non-null  str
#  3   year_of_birth         42290 non-null  float64
#  4   age_at_measurement    42269 non-null  float64
#  5   age_group             42269 non-null  str
#  6   race_concept_id       42300 non-null  int64
#  7   race_clean            42300 non-null  str
#  8   ethnicity_concept_id  42300 non-null  int64
#  9   ethnicity_clean       42300 non-null  str
#  10  measurement_date      42300 non-null  str
#  11  measurement_year      42300 non-null  int64
#  12  measurement_month     42300 non-null  str
#  13  weight                28284 non-null  float64
#  14  bmi                   26620 non-null  float64
#  15  triglycerides         15585 non-null  float64
#  16  hba1c                 15802 non-null  float64
#  17  Serum_Glucose         33091 non-null  float64
#  18  AST                   30196 non-null  float64
#  19  ALT                   30225 non-null  float64
#  20  Serum_Creatinine      33619 non-null  float64
#  21  Serum_Albumin         29921 non-null  float64
#  22  tsh                   450 non-null    float64
#  23  t3                    9611 non-null   float64
#  24  t4                    41812 non-null  float64
#  25  has_tsh               42300 non-null  int64
#  26  has_t3                42300 non-null  int64
#  27  has_t4                42300 non-null  int64
#  28  has_any_thyroid_test  42300 non-null  int64
# dtypes: float64(14), int64(9), str(6)
# memory usage: 9.4 MB
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
